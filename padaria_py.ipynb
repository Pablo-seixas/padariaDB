# %%
import pandas as pd
import os

# %%
desktop_path = os.path.expanduser("~/Desktop")

# %%
csv_path = os.path.join(desktop_path, "padaria.csv")

# %%
data = pd.read_csv(csv_path)

# %%
data
# Out:
#     id                             nome    cargo  salario
# 0    1                    Funcionário 1  Cargo 1   1500.0
# 1    2                    Funcionário 2  Cargo 2   2000.0
# 2    3                    Funcionário 3  Cargo 3   1800.0
# 3    4                    Funcionário 4  Cargo 1   1700.0
# 4    5                    Funcionário 5  Cargo 2   2100.0
# 5    6                    Funcionário 6  Cargo 3   1900.0
# 6    7                    Funcionário 7  Cargo 1   1600.0
# 7    8                    Funcionário 8  Cargo 2   2200.0
# 8    9                    Funcionário 9  Cargo 3   2000.0
# 9   10                   Funcionário 10  Cargo 1   1750.0
# 10  11                   Funcionário 11  Cargo 2   2300.0
# 11  12                   Funcionário 12  Cargo 3   2100.0
# 12  id                             nome      NaN      NaN
# 13   1                              Pão      NaN      NaN
# 14   2                             Doce      NaN      NaN
# ...

# %%
data.head()
# Out:
#   id           nome    cargo  salario
# 0  1  Funcionário 1  Cargo 1   1500.0
# 1  2  Funcionário 2  Cargo 2   2000.0
# 2  3  Funcionário 3  Cargo 3   1800.0
# 3  4  Funcionário 4  Cargo 1   1700.0
# 4  5  Funcionário 5  Cargo 2   2100.0

# %%
data_by_cargo = data.groupby('cargo')['salario'].mean()

# %%
data_by_cargo.plot(kind='bar', color='skyblue')
plt.title('Média de Salários por Cargo')
plt.xlabel('Cargo')
plt.ylabel('Média de Salário')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
data.plot(kind='scatter', x='id', y='salario', color='purple', alpha=0.7)
plt.title('Relação entre ID dos Funcionários e Salários')
plt.xlabel('ID dos Funcionários')
plt.ylabel('Salário')
plt.tight_layout()
plt.show()

# %%
import os
import matplotlib.pyplot as plt
data_by_cargo_count = data['cargo'].value_counts()
data_by_cargo_count.plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral'])
plt.title('Distribuição de Funcionários por Cargo')
plt.axis('equal')  
plt.tight_layout()
plt.show()
